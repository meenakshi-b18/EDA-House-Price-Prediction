# %%
# NumPy for numerical computing
import numpy as np

# Pandas for DataFrames
import pandas as pd
# pd.set_option('display.max_columns', 100)

# Matplotlib for visualization
import matplotlib.pyplot as plt
# display plots in the notebook
# %matplotlib inline 

# Seaborn for easier visualization
import seaborn as sns

# %%
# Load real estate data from CSV

data = pd.read_csv('real_estate.csv')

# %%
data.head()
# Out:
#    tx_price  beds  baths  sqft  year_built  lot_size  \
# 0    295850     1      1   584        2013         0
# 1    216500     1      1   612        1965         0
# 2    279900     1      1   615        1963         0
# 3    379900     1      1   618        2000     33541
# 4    340000     1      1   634        1992         0
#
#                    property_type exterior_walls                 roof  \
# 0  Apartment / Condo / Townhouse    Wood Siding                  NaN
# 1  Apartment / Condo / Townhouse          Brick  Composition Shingle
# 2  Apartment / Condo / Townhouse    Wood Siding                  NaN
# 3  Apartment / Condo / Townhouse    Wood Siding                  NaN
# 4  Apartment / Condo / Townhouse          Brick                  NaN
#
#    basement  restaurants  groceries  nightlife  cafes  shopping  \
# 0       NaN          107          9         30     19        89
# 1       1.0          105         15          6     13        87
# ...

# %%
# Dataframe dimensions

data.shape
# Out:
# (1883, 26)

# %%
# Column datatypes

data.dtypes
# Out:
# tx_price                int64
# beds                    int64
# baths                   int64
# sqft                    int64
# year_built              int64
# lot_size                int64
# property_type          object
# exterior_walls         object
# roof                   object
# basement              float64
# restaurants             int64
# groceries               int64
# nightlife               int64
# cafes                   int64
# shopping                int64
# arts_entertainment      int64
# beauty_spas             int64
# active_life             int64
# median_age              int64
# married                 int64
# college_grad            int64
# property_tax            int64
# insurance               int64
# median_school         float64
# num_schools             int64
# tx_year                 int64
# dtype: object

# %%
# Filter and display only data.dtypes that are 'object'

data.dtypes[data.dtypes == 'object']
# Out:
# property_type     object
# exterior_walls    object
# roof              object
# dtype: object

# %%
# Plot histogram grid
data.hist(figsize = (14,14))

# Clear the text "residue"
plt.show()

# %%
data.corr()
# Out:
#                     tx_price      beds     baths      sqft  year_built  \
# tx_price            1.000000  0.384046  0.389375  0.469573    0.033138
# beds                0.384046  1.000000  0.644572  0.691039   -0.011844
# baths               0.389375  0.644572  1.000000  0.682060    0.206141
# sqft                0.469573  0.691039  0.682060  1.000000    0.254589
# year_built          0.033138 -0.011844  0.206141  0.254589    1.000000
# lot_size            0.130558  0.164399  0.132976  0.246016    0.000068
# basement                 NaN       NaN       NaN       NaN         NaN
# restaurants        -0.038027 -0.495834 -0.350210 -0.353759   -0.106948
# groceries          -0.094314 -0.421412 -0.340024 -0.371167   -0.222443
# nightlife           0.009361 -0.440844 -0.306686 -0.281540   -0.080006
# cafes              -0.001398 -0.464289 -0.316836 -0.300969   -0.102209
# shopping           -0.038246 -0.388670 -0.259603 -0.275586   -0.121684
# ...

# %%
data.describe()
# Out:
#             tx_price         beds        baths         sqft   year_built  \
# count    1883.000000  1883.000000  1883.000000  1883.000000  1883.000000
# mean   422839.807754     3.420605     2.579926  2329.398832  1982.963887
# std    151462.593276     1.068554     0.945576  1336.991858    20.295945
# min    200000.000000     1.000000     1.000000   500.000000  1880.000000
# 25%    300000.000000     3.000000     2.000000  1345.000000  1970.000000
# 50%    392000.000000     3.000000     3.000000  1907.000000  1986.000000
# 75%    525000.000000     4.000000     3.000000  3005.000000  2000.000000
# max    800000.000000     5.000000     6.000000  8450.000000  2015.000000
#
#            lot_size  basement  restaurants    groceries    nightlife  \
# count  1.883000e+03    1657.0  1883.000000  1883.000000  1883.000000
# mean   1.339262e+04       1.0    40.210303     4.505045     5.074881
# std    4.494930e+04       0.0    46.867012     4.491029     8.464668
# ...

# %%
# Segment by property_type and display the means within each class
data.groupby('property_type').mean()
# Out:
#                                     tx_price      beds     baths         sqft  \
# property_type
# Apartment / Condo / Townhouse  366614.034869  2.601494  2.200498  1513.727273
# Single-Family                  464644.711111  4.029630  2.862037  2935.865741
#
#                                 year_built      lot_size  basement  \
# property_type
# Apartment / Condo / Townhouse  1988.936488   3944.239103       1.0
# Single-Family                  1978.523148  20417.666667       1.0
#
#                                restaurants  groceries  nightlife     cafes  \
# property_type
# Apartment / Condo / Townhouse    58.418431   5.919054   7.855542  8.037360
# Single-Family                    26.672222   3.453704   3.007407  3.308333
#
#                                 shopping  arts_entertainment  beauty_spas  \
# property_type
# Apartment / Condo / Townhouse  57.631382            4.840598    32.087173
# Single-Family                  28.289815            2.318519    16.970370
#
# ...

# %%
data.columns
# Out:
# Index(['tx_price', 'beds', 'baths', 'sqft', 'year_built', 'lot_size',
#        'property_type', 'exterior_walls', 'roof', 'basement', 'restaurants',
#        'groceries', 'nightlife', 'cafes', 'shopping', 'arts_entertainment',
#        'beauty_spas', 'active_life', 'median_age', 'married', 'college_grad',
#        'property_tax', 'insurance', 'median_school', 'num_schools', 'tx_year'],
#       dtype='object')

# %%
data[["tx_price","property_type","sqft"]].groupby(["property_type","sqft"]).describe()
# Out:
#                                    tx_price                           \
#                                       count      mean            std
# property_type                 sqft
# Apartment / Condo / Townhouse 500       1.0  275000.0            NaN
#                               584       1.0  295850.0            NaN
#                               612       1.0  216500.0            NaN
#                               615       1.0  279900.0            NaN
#                               618       1.0  379900.0            NaN
#                               634       1.0  340000.0            NaN
#                               641       1.0  265000.0            NaN
#                               650       1.0  388100.0            NaN
#                               660       1.0  240000.0            NaN
#                               664       1.0  250000.0            NaN
#                               669       1.0  335000.0            NaN
# ...

# %%
data[["tx_price","property_type","lot_size"]].groupby(["property_type","lot_size"]).describe()
# Out:
#                                        tx_price                                \
#                                           count           mean            std
# property_type                 lot_size
# Apartment / Condo / Townhouse 0           332.0  338368.111446  115165.859647
#                               784           1.0  538000.000000            NaN
#                               792           1.0  719981.000000            NaN
#                               835           1.0  538430.000000            NaN
#                               915           1.0  325900.000000            NaN
#                               937           1.0  342000.000000            NaN
#                               1000          1.0  335000.000000            NaN
#                               1050          1.0  358000.000000            NaN
#                               1057          1.0  422000.000000            NaN
# ...

# %%
data[["tx_price","restaurants","groceries", "nightlife","cafes", "shopping", "arts_entertainment", "beauty_spas", "active_life"]].groupby(["restaurants","groceries", "nightlife","cafes", "shopping", "arts_entertainment", "beauty_spas", "active_life"]).describe()
# Out:
#                                                                                           tx_price  \
#                                                                                              count
# restaurants groceries nightlife cafes shopping arts_entertainment beauty_spas active_life
# 0           0         0         0     0        0                  0           0               22.0
#                                                                               1               15.0
#                                                                               2                3.0
#                                                                               3                1.0
#                                                                               4                2.0
#                                                                               5                2.0
# ...

# %%
data[["tx_price","married","property_type"]].groupby(["married", "property_type"]).describe()
# Out:
#                                       tx_price                                \
#                                          count           mean            std
# married property_type
# 11      Apartment / Condo / Townhouse      2.0  459000.000000   22627.416998
# 13      Apartment / Condo / Townhouse      8.0  332800.000000  160864.867868
#         Single-Family                      1.0  280000.000000            NaN
# 15      Apartment / Condo / Townhouse     13.0  389230.769231  123074.955631
# 16      Apartment / Condo / Townhouse      4.0  319694.750000   33204.185132
# 18      Apartment / Condo / Townhouse      2.0  713750.000000   93691.648507
# 20      Apartment / Condo / Townhouse      4.0  336987.500000   99241.627481
# 21      Apartment / Condo / Townhouse      8.0  384653.750000   64650.707418
# 22      Apartment / Condo / Townhouse      5.0  275580.000000   22700.925091
# 23      Apartment / Condo / Townhouse      5.0  331000.000000   60579.493230
# ...

# %%
# Make the figsize 7 x 6
plt.figure(figsize=(15,8))

# Calculate correlations between numeric features
correlations = data.corr()

# Plot heatmap of correlations
sns.heatmap(correlations, linewidths=.5)

# %%
# For categorical values

data.describe(include = ["object"])
# Out:
#         property_type exterior_walls                 roof
# count            1883           1660                 1529
# unique              2             16                   16
# top     Single-Family          Brick  Composition Shingle
# freq             1080            687                 1179

# %% [markdown]
# **Missing Value imputation**

# %%
data = data.drop_duplicates()
print( data.shape )
# Out:
# (1883, 26)

# %%
data[["tx_price","property_type","basement"]].groupby(["property_type","basement"]).describe()
# Out:
#                                        tx_price                                \
#                                           count           mean            std
# property_type                 basement
# Apartment / Condo / Townhouse 1.0         629.0  363013.550079  117212.316186
# Single-Family                 1.0        1028.0  469313.848249  157991.285063
#
#                                                                        \
#                                              min        25%       50%
# property_type                 basement
# Apartment / Condo / Townhouse 1.0       200000.0  280000.00  335000.0
# Single-Family                 1.0       200000.0  342398.75  455000.0
#
#
#                                              75%       max
# property_type                 basement
# Apartment / Condo / Townhouse 1.0       416000.0  790830.0
# Single-Family                 1.0       585000.0  800000.0
